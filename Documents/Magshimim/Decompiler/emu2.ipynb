# %%
A = 0 # 8 bit accumulation 
PC = 0x100 # 12 bit pointer

MEM = [0]*0x1000
SEC_BLOCKED = [False]*0x1000

# %%
# load ROM

with open('rom', 'rb') as f:
    data = f.read()
    i = 0x100
    for byte in data:
        MEM[i] = byte
        i+=1

# %%
probs = [] # command code

# %%
def step():
    global MEM, A, PC, probs
    
    c1 = MEM[PC]
    c2 = MEM[PC+1]

    PC += 2 # 2 bytes per instruction
    
    if c1 == 0:
        A = (A + c2) % 0x100
#         print("add")
    elif c1 == 1:
        A = c2
#         print("set")
    elif c1 == 2:
        A = A ^ c2
#         print("xor")
    elif c1 == 3:
        A = A | c2
#         print("or")
    elif c1 == 4:
        A = A & c2
#         print("and")
    elif c1&0xF0 == 0x80: # first digit
        A = MEM[c1&0xF * 0x100 + c2]
#         print("addr set")
    elif c1&0xF0 == 0xD0:
        if not SEC_BLOCKED[c1&0xF * 0x100 + c2]:
            MEM[c1&0xF * 0x100 + c2] = A ^ MEM[c1&0xF * 0x100 + c2]
#             print("addr reverse xor")
    elif c1&0xF0 == 0xF0:
        if not SEC_BLOCKED[c1&0xF * 0x100 + c2]:
            MEM[c1&0xF * 0x100 + c2] = A
#             print("addr reverse set")
    elif c1 == 0x13 and c2 == 0x37:
        print(chr(A),end='')
#         print("print")
    elif c1&0xF0 == 0x20:
        PC = c1&0xF * 0x100 + c2
#         print("jmp")
    elif c1&0xF0 == 0x30:
        if A == 0:
            PC = c1&0xF * 0x100 + c2
#             print("jmp if 0")
    elif c1&0xF0 == 0x40:
        if A == 1:
            PC = c1&0xF * 0x100 + c2 
#             print("jmp if 1")
    elif c1&0xF0 == 0x50:
        if A == 255:
            PC = c1&0xF * 0x100 + c2 
#             print("jmp if 255")
    elif c1 == 0x60:
        if A == c2:
            A = 0
        elif A < c2:
            A = 1
        else:
            A = 255
#         print("cmp, res =", A)
    elif c1&0xF0 == 0x70:
        if A == MEM[c1&0xF * 0x100 + c2]:
            A = 0
        elif A < MEM[c1&0xF * 0x100 + c2]:
            A = 1
        else:
            A = 255
#         print("addr cmp, res =", A)
    elif c1 == 0xBE and c2 == 0xEF:
        A=0x42
        PC=0x100
#         print("LIFE")
    elif c1&0xF0 == 0x90:
        SEC_BLOCKED[c1&0xF * 0x100 + c2] = True
#         print("block", c1&0xF * 0x100 + c2)
    elif c1&0xF0 == 0xA0:
        SEC_BLOCKED[c1&0xF * 0x100 + c2] = False
#         print("unblock", c1&0xF * 0x100 + c2)
    elif c1&0xF0 == 0xC0:
        if not SEC_BLOCKED[c1&0xF * 0x100 + c2]:
            MEM[c1&0xF * 0x100 + c2] = MEM[c1&0xF * 0x100 + c2] ^ 0x42
#             print("forbnicate", c1&0xF * 0x100 + c2)
    elif c1==0xEE and c2==0xEE:
#         print("NOP")
        pass
    else:
#         print("ERROR INSTRUCTION")
        A-=1
        probs.append((c1,c2))

# %%
def debug():
    step()
    print('PC',hex(PC))
    print('A',hex(A))

# %%
# print(MEM[0x121], MEM[0x122])
while PC < 0x1000:#0:
    step()
# Out:
# XÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑÑ
# ...

# %%
probs

# %%
hex(66)
# Out:
# '0x42'
